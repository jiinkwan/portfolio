# %% [markdown]
# # Building a Spam Filter with Naive Bayes
#
# we are goingt to build spam filter using Naive Bayes algorithm with the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/sms+spam+collection). The goal is to build practical sms spam filter.

# %% [markdown]
# ## Exploring the Dataset

# %%
import pandas as pd
import numpy as np

# %%
spam_data = pd.read_csv('SMSSpamCollection', sep='\t', header = None, names=['Label','SMS'])

# %%
print(spam_data.shape)
spam_data.head()
# Out:
# (5572, 2)
#   Label                                                SMS
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
print(spam_data['Label'].value_counts())
spam_data['Label'].value_counts(normalize = True)
# Out:
# ham     4825
# spam     747
# Name: Label, dtype: int64
# ham     0.865937
# spam    0.134063
# Name: Label, dtype: float64

# %% [markdown]
# From the result above, we have total of 5572 rows with label and content column. 86.6% of them are ham and the other 13.4% of them are spam.

# %% [markdown]
# ## Traning and Test Set
#
# We are going to keep 80% of the data set for training, and 20% for testing. The goal is to create a spam filter that classifies new messages with an accuracy greater than 80%. The 20% of the data will be used for that.

# %%
train_data = spam_data.sample(frac = 1, random_state = 1)[0:4458].reset_index()
test_data = spam_data.sample(frac = 1, random_state = 1)[4458:].reset_index()

# %%
train_data['Label'].value_counts(normalize = True)
# Out:
# ham     0.86541
# spam    0.13459
# Name: Label, dtype: float64

# %%
test_data['Label'].value_counts(normalize = True)
# Out:
# ham     0.868043
# spam    0.131957
# Name: Label, dtype: float64

# %% [markdown]
# With the randomize sample, it looks like we have quite similar ratio of ham and spam in the both data sets.

# %% [markdown]
# ## Letter Case and Punctuation
#
# We mentioned that we are going to use Naive Bayes Algorithm to classify whether the message is spam or ham. In order to do that, we need to quantify the number of occurance for the words. We need to clean the data a bit.

# %%
# Removing the punctuation and lower the character.
# regular expression \W detect any character that is not from a-z, A-Z, or 0-9
train_data['SMS']= train_data['SMS'].str.replace(r'\W', ' ').str.lower()
test_data['SMS']= test_data['SMS'].str.replace(r'\W', ' ').str.lower()

# %% [markdown]
# ## Creating the Vocabulary
#
# To apply Naive Bayes, we need a vocabulary, set of unique words, to count the occurance of each words.

# %%
# Split words
vocabulary = []
train_data['SMS'] = train_data['SMS'].str.split()
for sms in train_data['SMS']:
    for word in sms:
        vocabulary.append(word)
        

vocabulary = list(set(vocabulary)) # removing duplicate

# %% [markdown]
# # The Final Training Set

# %%
word_counts_per_sms = {unique_word: [0] * len(train_data['SMS']) for unique_word in vocabulary}

for index, sms in enumerate(train_data['SMS']):
    for word in sms:
        #print(word, index)
        word_counts_per_sms[word][index] += 1

# %%
# Concating the data sets
train_data_final = pd.concat([train_data,pd.DataFrame(word_counts_per_sms)], axis = 1)

# %%
train_data_final.shape
# Out:
# (4458, 7786)

# %% [markdown]
# ## Calculating Constants First
#
# Naive Bayes algorithm will need to know the probabilty values of the two equations below to classify new messages:
#
# \begin{equation}
# P(Spam | w_1,w_2, ..., w_n) \propto P(Spam) \cdot \prod_{i=1}^{n}P(w_i|Spam) \\
# P(Ham | w_1,w_2, ..., w_n) \propto P(Ham) \cdot \prod_{i=1}^{n}P(w_i|Ham)
# \end{equation}
#
# Also, to calculate P(wi|Spam) and P(wi|Ham) inside the formulas above, recall that we need to use these equations:
#
# \begin{equation}
# P(w_i|Spam) = \frac{N_{w_i|Spam} + \alpha}{N_{Spam} + \alpha \cdot N_{Vocabulary}} \\
# P(w_i|Ham) = \frac{N_{w_i|Ham} + \alpha}{N_{Ham} + \alpha \cdot N_{Vocabulary}}
# \end{equation}
#
# The values we need to find out are:
#
# - $P(Spam)$
# - $P(Ham)$
# - $N_{Spam}$
# - $N_{Ham}$
# - $N_{Vovabulary}$
#
# Also it's worth mentioning that we are going to use Laplace smoothing wiwht set $\alpha = 1$.

# %%
p_ham = train_data_final['Label'].value_counts(normalize = True)[0]
p_spam = train_data_final['Label'].value_counts(normalize = True)[1]
alpha = 1

# %%
n_spam = train_data_final.loc[train_data_final['Label'] == 'spam','SMS'].apply(len).sum()
n_ham = train_data_final.loc[train_data_final['Label'] == 'ham','SMS'].apply(len).sum()
n_voc = len(vocabulary)

# %% [markdown]
# ## Caculating Parameters

# %%
voc_spam = {word : 0 for word in vocabulary}
voc_ham = {word : 0 for word in vocabulary}

# %%
train_spam = train_data_final[train_data_final['Label'] == 'spam']
train_ham = train_data_final[train_data_final['Label'] == 'ham']

# %%
for key in voc_spam.keys():
    voc_spam[key] = (train_spam[key].sum() + alpha)/((n_spam+alpha)*n_voc)
    voc_ham[key] = (train_ham[key].sum() + alpha) /((n_ham+alpha)*n_voc)

# %% [markdown]
# # Classifying a New Message

# %%
import re

def classify(message):

    message = re.sub('\W', ' ', message)
    message = message.lower()
    message = message.split()

    p_spam_given_message = p_spam
    p_ham_given_message = p_ham
    
    for word in message:
        if word in voc_spam:
            p_spam_given_message *= voc_spam[word]
            
        if word in voc_ham:
            p_ham_given_message *= voc_ham[word]
           
    print('P(Spam|message):', p_spam_given_message)
    print('P(Ham|message):', p_ham_given_message)

    if p_ham_given_message > p_spam_given_message:
        print('Label: Ham')
    elif p_ham_given_message < p_spam_given_message:
        print('Label: Spam')
    else:
        print('Equal proabilities, have a human classify this!')

# %%
classify('WINNER!! This is the secret code to unlock the money: C3421.')
# Out:
# P(Spam|message): 5.32218937227696e-59
# P(Ham|message): 5.821370428319695e-62
# Label: Spam

# %% [markdown]
# ## Measuring the Spam Filter's Accuracy

# %%
correct = 0
total = test_data.shape[0]

# %%
for sms in test_data.iterrows():
    type(classify(sms[1]['SMS']))
# Out:
# P(Spam|message): 3.642143530033919e-52
# P(Ham|message): 6.0010715419901245e-46
# Label: Ham
# P(Spam|message): 1.2293083708317337e-67
# P(Ham|message): 2.906292881293275e-63
# Label: Ham
# P(Spam|message): 1.7535120272013756e-190
# P(Ham|message): 2.509488744804041e-209
# Label: Spam
# P(Spam|message): 1.4246578986478367e-67
# P(Ham|message): 4.4528673877738666e-63
# Label: Ham
# P(Spam|message): 1.6266213529849802e-142
# P(Ham|message): 1.266516954358826e-134
# Label: Ham
# P(Spam|message): 5.1188669624209995e-229
# P(Ham|message): 2.5121775911523986e-211
# Label: Ham
# P(Spam|message): 2.5033279355379428e-15
# P(Ham|message): 3.2738180476224296e-13
# Label: Ham
# P(Spam|message): 1.8314685133002468e-96
# P(Ham|message): 1.9553689280235748e-92
# Label: Ham
# P(Spam|message): 7.280753648587613e-91
# P(Ham|message): 7.775465655266126e-86
# Label: Ham
# P(Spam|message): 2.8522608676786166e-34
# P(Ham|message): 4.2774353637040575e-34
# Label: Ham
# P(Spam|message): 9.546426644937758e-31
# P(Ham|message): 8.337106647294401e-28
# Label: Ham
# P(Spam|message): 1.0994163406142953e-93
# P(Ham|message): 7.920717867147567e-88
# Label: Ham
# P(Spam|message): 1.6002953202801962e-206
# P(Ham|message): 3.213278890365873e-199
# Label: Ham
# P(Spam|message): 6.453359967976415e-107
# P(Ham|message): 7.044483477775882e-101
# Label: Ham
# P(Spam|message): 5.700448726422074e-25
# P(Ham|message): 5.577635913401427e-23
# Label: Ham
# P(Spam|message): 2.4286644234990637e-81
# P(Ham|message): 1.0257462305060233e-73
# Label: Ham
# P(Spam|message): 5.044221594248804e-236
# P(Ham|message): 3.068467024149784e-224
# Label: Ham
# P(Spam|message): 2.782894148077006e-147
# P(Ham|message): 2.651456806547204e-143
# Label: Ham
# P(Spam|message): 3.9992164251352834e-51
# P(Ham|message): 1.7030579201376092e-50
# Label: Ham
# P(Spam|message): 2.4228744910127515e-175
# P(Ham|message): 2.5085190374509533e-197
# Label: Spam
# P(Spam|message): 2.1064300198416633e-50
# P(Ham|message): 8.331871687759998e-47
# Label: Ham
# P(Spam|message): 3.1545147024252815e-47
# P(Ham|message): 1.80481555245699e-45
# Label: Ham
# P(Spam|message): 1.3550780972523329e-21
# P(Ham|message): 5.188415988905472e-19
# Label: Ham
# P(Spam|message): 1.0482976444275853e-78
# P(Ham|message): 1.0498532594125848e-74
# Label: Ham
# P(Spam|message): 7.751468500521442e-70
# P(Ham|message): 2.543308089227612e-67
# Label: Ham
# P(Spam|message): 9.628184367453627e-16
# P(Ham|message): 3.47489130792995e-13
# Label: Ham
# P(Spam|message): 9.595147622327861e-250
# P(Ham|message): 1.3580454060380568e-239
# Label: Ham
# P(Spam|message): 6.821906984256067e-59
# P(Ham|message): 1.6828600508257273e-54
# Label: Ham
# P(Spam|message): 1.47180664926953e-197
# P(Ham|message): 4.49472139483085e-223
# Label: Spam
# P(Spam|message): 1.0465780168085152e-171
# P(Ham|message): 4.80361694191134e-165
# Label: Ham
# P(Spam|message): 2.152715660870328e-202
# P(Ham|message): 3.354181604241687e-221
# Label: Spam
# P(Spam|message): 6.248775664273881e-52
# P(Ham|message): 5.4715550309669334e-45
# Label: Ham
# P(Spam|message): 1.3672477846995376e-199
# P(Ham|message): 4.665890860542976e-188
# Label: Ham
# P(Spam|message): 6.908009560228323e-169
# P(Ham|message): 3.6110269889371155e-162
# Label: Ham
# P(Spam|message): 4.543277372527542e-137
# P(Ham|message): 1.346788379734285e-124
# Label: Ham
# P(Spam|message): 1.0448113497584862e-174
# P(Ham|message): 6.336621771922378e-169
# Label: Ham
# P(Spam|message): 3.743811810009706e-126
# P(Ham|message): 1.4727480461884403e-122
# Label: Ham
# P(Spam|message): 4.726320930717966e-72
# P(Ham|message): 9.191235155299254e-68
# Label: Ham
# P(Spam|message): 3.495119040024809e-189
# P(Ham|message): 2.1964849496029447e-181
# Label: Ham
# P(Spam|message): 2.5961537393305226e-106
# P(Ham|message): 3.555812519271381e-99
# Label: Ham
# P(Spam|message): 2.7578963475989618e-49
# P(Ham|message): 3.56494103250696e-46
# Label: Ham
# P(Spam|message): 4.572817149748789e-218
# P(Ham|message): 9.58725202563008e-242
# Label: Spam
# P(Spam|message): 3.4033164738303707e-81
# P(Ham|message): 1.4488272437133334e-75
# Label: Ham
# P(Spam|message): 8.539230867219906e-154
# P(Ham|message): 1.2615869723687709e-144
# Label: Ham
# P(Spam|message): 5.032509953861917e-59
# P(Ham|message): 9.541539637012637e-55
# Label: Ham
# P(Spam|message): 1.3775507424152608e-33
# P(Ham|message): 2.2109582873088362e-29
# Label: Ham
# P(Spam|message): 2.0035462388033407e-96
# P(Ham|message): 3.8882345783377313e-90
# Label: Ham
# P(Spam|message): 3.3858143681451944e-208
# P(Ham|message): 2.6610357361739494e-197
# Label: Ham
# P(Spam|message): 5.463560177743111e-61
# P(Ham|message): 4.7274747505835077e-54
# Label: Ham
# P(Spam|message): 5.695982616465774e-46
# P(Ham|message): 2.974063777811689e-43
# Label: Ham
# P(Spam|message): 2.327654972400671e-134
# P(Ham|message): 1.9932991444413198e-126
# Label: Ham
# P(Spam|message): 2.001004577005065e-177
# P(Ham|message): 1.6000442480761585e-182
# Label: Spam
# P(Spam|message): 3.5706418593969305e-103
# P(Ham|message): 1.691964306543777e-92
# Label: Ham
# P(Spam|message): 8.317799685938488e-83
# P(Ham|message): 4.683309073004558e-77
# Label: Ham
# P(Spam|message): 9.549224231116104e-121
# P(Ham|message): 6.277255044003353e-114
# Label: Ham
# P(Spam|message): 9.69387772221428e-36
# P(Ham|message): 4.641482066622818e-33
# Label: Ham
# P(Spam|message): 9.593646288929278e-34
# P(Ham|message): 2.297187241490998e-33
# Label: Ham
# P(Spam|message): 1.1758910714263002e-199
# P(Ham|message): 6.999312909760992e-218
# Label: Spam
# P(Spam|message): 1.0156905451104428e-92
# P(Ham|message): 7.910575745744325e-88
# Label: Ham
# P(Spam|message): 2.787680904058543e-42
# P(Ham|message): 2.04432761255945e-39
# Label: Ham
# P(Spam|message): 4.7198968826993465e-52
# P(Ham|message): 1.378538832312561e-49
# Label: Ham
# P(Spam|message): 1.3775507424152607e-32
# P(Ham|message): 3.8613536119276787e-28
# Label: Ham
# P(Spam|message): 1.1666782857481465e-108
# P(Ham|message): 5.4212880643388363e-104
# Label: Ham
# P(Spam|message): 1.516930140322634e-79
# P(Ham|message): 5.984265481448688e-75
# Label: Ham
# P(Spam|message): 1.7855693450126744e-55
# P(Ham|message): 7.434686342442389e-54
# Label: Ham
# P(Spam|message): 1.1684147021638278e-69
# P(Ham|message): 2.4535963376110225e-67
# Label: Ham
# P(Spam|message): 5.658484061998014e-79
# P(Ham|message): 4.780158625509494e-69
# Label: Ham
# P(Spam|message): 2.0559409703738495e-36
# P(Ham|message): 2.6653411795292717e-34
# Label: Ham
# P(Spam|message): 7.746378264122529e-166
# P(Ham|message): 3.39232539723709e-177
# Label: Spam
# P(Spam|message): 1.4120825845165535e-22
# P(Ham|message): 1.0804981804075237e-18
# Label: Ham
# P(Spam|message): 1.4501511610349128e-63
# P(Ham|message): 3.5002842679012615e-60
# Label: Ham
# P(Spam|message): 0.0
# P(Ham|message): 0.0
# Equal proabilities, have a human classify this!
# P(Spam|message): 4.628570494515275e-31
# P(Ham|message): 5.879949299434437e-28
# Label: Ham
# P(Spam|message): 1.4117124715677483e-110
# P(Ham|message): 1.709599842409981e-107
# Label: Ham
# P(Spam|message): 2.9612577943752724e-141
# P(Ham|message): 5.5964199765174287e-132
# Label: Ham
# P(Spam|message): 2.539101528419808e-29
# P(Ham|message): 5.087491750029248e-27
# Label: Ham
# P(Spam|message): 1.590150266361934e-190
# P(Ham|message): 1.819422051374948e-183
# Label: Ham
# P(Spam|message): 1.3437844953892923e-90
# P(Ham|message): 2.3704901152444174e-85
# Label: Ham
# P(Spam|message): 8.687332814436778e-53
# P(Ham|message): 4.572847418387703e-50
# Label: Ham
# P(Spam|message): 2.0358745451507402e-24
# P(Ham|message): 1.0531140437124942e-20
# Label: Ham
# P(Spam|message): 1.941991730077718e-74
# P(Ham|message): 1.183769155818204e-65
# Label: Ham
# P(Spam|message): 1.6820617440166133e-131
# P(Ham|message): 1.8668156277554413e-120
# Label: Ham
# P(Spam|message): 3.01505278225144e-68
# P(Ham|message): 6.581845649093681e-66
# Label: Ham
# P(Spam|message): 3.335376204382551e-162
# P(Ham|message): 1.1111178649770875e-157
# Label: Ham
# P(Spam|message): 3.8803424865314716e-160
# P(Ham|message): 5.653028683078819e-175
# Label: Spam
# P(Spam|message): 1.0834559598728277e-149
# P(Ham|message): 6.66947150852839e-141
# Label: Ham
# P(Spam|message): 1.0060511804937576e-78
# P(Ham|message): 1.6033353433877338e-74
# Label: Ham
# P(Spam|message): 2.762962059649338e-88
# P(Ham|message): 1.8060784073076533e-82
# Label: Ham
# P(Spam|message): 4.074303753933743e-49
# P(Ham|message): 3.1260219401246884e-46
# Label: Ham
# P(Spam|message): 5.616508749445205e-166
# P(Ham|message): 6.391475845153892e-174
# Label: Spam
# P(Spam|message): 9.616799027328374e-159
# P(Ham|message): 4.669202747261025e-146
# Label: Ham
# P(Spam|message): 2.9186429064811893e-136
# P(Ham|message): 1.0753972630273163e-153
# Label: Spam
# P(Spam|message): 1.3840646479539528e-44
# P(Ham|message): 1.117786443928681e-40
# Label: Ham
# P(Spam|message): 1.1560316299261343e-189
# P(Ham|message): 4.53365632797864e-186
# Label: Ham
# P(Spam|message): 4.1531840721075104e-23
# P(Ham|message): 2.710018432125632e-21
# Label: Ham
# P(Spam|message): 8.496979459188946e-66
# P(Ham|message): 4.659792798696925e-62
# Label: Ham
# P(Spam|message): 1.3085456706444873e-65
# P(Ham|message): 2.0118203989653683e-62
# Label: Ham
# P(Spam|message): 6.384909845881522e-39
# P(Ham|message): 6.917498050912021e-37
# Label: Ham
# P(Spam|message): 0.0
# P(Ham|message): 0.0
# Equal proabilities, have a human classify this!
# P(Spam|message): 3.246054796922818e-106
# P(Ham|message): 1.3600542758092046e-97
# Label: Ham
# P(Spam|message): 6.894808118843949e-113
# P(Ham|message): 1.2475436535578243e-101
# Label: Ham
# P(Spam|message): 2.4724900974684688e-61
# P(Ham|message): 1.1239154631345284e-56
# Label: Ham
# P(Spam|message): 2.7713104711722715e-70
# P(Ham|message): 7.774763904059997e-68
# Label: Ham
# P(Spam|message): 1.5179616289339598e-42
# P(Ham|message): 2.3023096290262275e-40
# Label: Ham
# P(Spam|message): 8.48961155686046e-244
# P(Ham|message): 4.254471873817977e-229
# Label: Ham
# P(Spam|message): 7.282648947795847e-92
# P(Ham|message): 7.366305440826429e-89
# Label: Ham
# P(Spam|message): 2.0693110165631114e-69
# P(Ham|message): 1.1687664258127234e-65
# Label: Ham
# P(Spam|message): 1.984621819818056e-52
# P(Ham|message): 1.5214435538586004e-49
# Label: Ham
# P(Spam|message): 4.0227208424312425e-108
# P(Ham|message): 8.372862839071168e-103
# Label: Ham
# P(Spam|message): 1.6220785915907254e-75
# P(Ham|message): 2.1249737739200765e-70
# Label: Ham
# P(Spam|message): 4.76774466445572e-112
# P(Ham|message): 6.587509122406518e-104
# Label: Ham
# P(Spam|message): 3.5107166997361065e-53
# P(Ham|message): 8.868391692835394e-51
# Label: Ham
# P(Spam|message): 1.1362984444799294e-244
# P(Ham|message): 1.0203466503025863e-232
# Label: Ham
# P(Spam|message): 2.6946287006068785e-55
# P(Ham|message): 1.1807059197921252e-51
# Label: Ham
# P(Spam|message): 9.025239134166625e-206
# P(Ham|message): 9.975121055718016e-200
# Label: Ham
# P(Spam|message): 2.3202404809639853e-149
# P(Ham|message): 2.648119413060732e-146
# Label: Ham
# P(Spam|message): 5.73254639821833e-178
# P(Ham|message): 2.7264565995466187e-163
# Label: Ham
# P(Spam|message): 1.3820407236012291e-222
# P(Ham|message): 1.967893832966479e-247
# Label: Spam
# P(Spam|message): 1.930858008805465e-67
# P(Ham|message): 8.22321009043302e-61
# Label: Ham
# P(Spam|message): 1.9764860467990745e-88
# P(Ham|message): 9.717162419850495e-87
# Label: Ham
# P(Spam|message): 9.32480815097376e-235
# P(Ham|message): 2.7395061471997215e-252
# Label: Spam
# P(Spam|message): 5.17449912463092e-142
# P(Ham|message): 9.560792196415497e-154
# Label: Spam
# P(Spam|message): 2.402537327321409e-133
# P(Ham|message): 4.7427696334042e-122
# Label: Ham
# P(Spam|message): 3.323079263965948e-188
# P(Ham|message): 2.0216921164491195e-178
# Label: Ham
# P(Spam|message): 0.0
# P(Ham|message): 0.0
# Equal proabilities, have a human classify this!
# P(Spam|message): 1.232295179891432e-26
# P(Ham|message): 5.661252960317686e-26
# Label: Ham
# P(Spam|message): 2.2104512553894e-51
# P(Ham|message): 4.332490958513512e-49
# Label: Ham
# P(Spam|message): 4.0181420884385855e-185
# P(Ham|message): 7.931197029198563e-178
# Label: Ham
# P(Spam|message): 4.5210621951356836e-74
# P(Ham|message): 9.067498430772807e-70
# Label: Ham
# P(Spam|message): 1.712081661587278e-58
# P(Ham|message): 8.428953956055362e-53
# Label: Ham
# P(Spam|message): 5.754807793937591e-37
# P(Ham|message): 2.7493050570436857e-35
# Label: Ham
# P(Spam|message): 7.42230746963431e-157
# P(Ham|message): 9.406505219368698e-157
# Label: Ham
# P(Spam|message): 1.2983157388755e-70
# P(Ham|message): 2.5710302572052295e-68
# Label: Ham
# P(Spam|message): 2.8718112752059805e-36
# P(Ham|message): 7.353216230797861e-35
# Label: Ham
# P(Spam|message): 3.0875980937474387e-110
# P(Ham|message): 7.74495945655658e-104
# Label: Ham
# P(Spam|message): 3.1798582681141867e-175
# P(Ham|message): 3.786512583085285e-178
# Label: Spam
# P(Spam|message): 3.2148451772773703e-232
# P(Ham|message): 2.8207978139700858e-219
# Label: Ham
# P(Spam|message): 1.0945966233632153e-154
# P(Ham|message): 2.955632427617177e-172
# Label: Spam
# P(Spam|message): 2.75604400471569e-36
# P(Ham|message): 3.178113813534933e-33
# Label: Ham
# P(Spam|message): 1.537970984774381e-38
# P(Ham|message): 7.064826755117858e-34
# Label: Ham
# P(Spam|message): 2.4465582228091446e-97
# P(Ham|message): 4.684503562072017e-93
# Label: Ham
# P(Spam|message): 1.54712248576503e-162
# P(Ham|message): 3.4488470200275934e-170
# Label: Spam
# P(Spam|message): 8.948194820505488e-37
# P(Ham|message): 1.554827050037535e-32
# Label: Ham
# P(Spam|message): 1.1006573722027625e-208
# P(Ham|message): 2.023272444598521e-196
# Label: Ham
# P(Spam|message): 3.154427007836939e-125
# P(Ham|message): 8.154755104206844e-118
# Label: Ham
# P(Spam|message): 9.315707104571807e-203
# P(Ham|message): 5.806231009850189e-187
# Label: Ham
# P(Spam|message): 3.8640889177109568e-168
# P(Ham|message): 3.229662457292522e-157
# Label: Ham
# P(Spam|message): 1.8487491753741414e-128
# P(Ham|message): 1.9935279746065477e-142
# Label: Spam
# P(Spam|message): 1.9908330577890961e-131
# P(Ham|message): 8.094861287145208e-123
# Label: Ham
# P(Spam|message): 2.4393691531115155e-184
# P(Ham|message): 1.073516957289398e-200
# Label: Spam
# P(Spam|message): 1.6602104257737954e-50
# P(Ham|message): 9.620514588212697e-47
# Label: Ham
# P(Spam|message): 2.441371474631321e-184
# P(Ham|message): 4.26504266874672e-168
# Label: Ham
# P(Spam|message): 7.736323271572815e-23
# P(Ham|message): 4.3070547593833414e-24
# Label: Spam
# P(Spam|message): 3.304649423186841e-109
# P(Ham|message): 1.0382785841703074e-101
# Label: Ham
# P(Spam|message): 5.749071091515052e-137
# P(Ham|message): 1.1245204789064582e-123
# Label: Ham
# P(Spam|message): 1.2859634721694e-168
# P(Ham|message): 3.583883417149598e-161
# Label: Ham
# P(Spam|message): 2.5732439114386555e-43
# P(Ham|message): 4.192627600335925e-40
# Label: Ham
# P(Spam|message): 5.097040541839086e-51
# P(Ham|message): 2.546241478766751e-47
# Label: Ham
# P(Spam|message): 3.653523345568769e-119
# P(Ham|message): 1.0940901297532664e-112
# Label: Ham
# P(Spam|message): 3.9088791266894214e-23
# P(Ham|message): 4.101490782230954e-24
# Label: Spam
# P(Spam|message): 6.439893305266048e-91
# P(Ham|message): 3.7679231198446625e-80
# Label: Ham
# P(Spam|message): 2.480425912693952e-72
# P(Ham|message): 1.5509239595626443e-65
# Label: Ham
# P(Spam|message): 2.019164341251601e-158
# P(Ham|message): 1.4874032246097657e-149
# Label: Ham
# P(Spam|message): 1.3165963733295837e-37
# P(Ham|message): 2.1592573299108904e-35
# Label: Ham
# P(Spam|message): 2.6282524900961177e-90
# P(Ham|message): 1.441086034038246e-86
# Label: Ham
# P(Spam|message): 1.7476943008799786e-40
# P(Ham|message): 2.312860471794366e-37
# Label: Ham
# P(Spam|message): 1.9912810919207056e-158
# P(Ham|message): 3.557957683724962e-148
# Label: Ham
# P(Spam|message): 4.256187246896513e-177
# P(Ham|message): 1.63476638095366e-194
# Label: Spam
# P(Spam|message): 2.0116427162341068e-160
# P(Ham|message): 2.8370474359057617e-152
# Label: Ham
# P(Spam|message): 6.0399639971559066e-176
# P(Ham|message): 7.854869544031416e-186
# Label: Spam
# P(Spam|message): 1.0659229662900103e-61
# P(Ham|message): 4.800538478128897e-56
# Label: Ham
# P(Spam|message): 3.233313259263719e-171
# P(Ham|message): 3.4180524555551275e-160
# Label: Ham
# P(Spam|message): 7.450291384975917e-223
# P(Ham|message): 3.2704530785255945e-211
# Label: Ham
# P(Spam|message): 1.1216316108094376e-43
# P(Ham|message): 1.924123254467617e-39
# Label: Ham
# P(Spam|message): 1.0089667737048914e-134
# P(Ham|message): 4.437574835217497e-125
# Label: Ham
# P(Spam|message): 4.884908159757466e-87
# P(Ham|message): 1.6169645449853116e-78
# Label: Ham
# P(Spam|message): 6.130793825938711e-42
# P(Ham|message): 3.7983901420859584e-41
# Label: Ham
# P(Spam|message): 3.33151914977611e-64
# P(Ham|message): 4.7455876041438965e-63
# Label: Ham
# P(Spam|message): 1.100277328981917e-27
# P(Ham|message): 2.8777964696756354e-25
# Label: Ham
# P(Spam|message): 2.2313185014852115e-23
# P(Ham|message): 3.2736357024342095e-20
# Label: Ham
# P(Spam|message): 2.144931127637496e-172
# P(Ham|message): 2.5229403401916674e-181
# Label: Spam
# P(Spam|message): 8.919138602235208e-188
# P(Ham|message): 3.468896272160334e-205
# Label: Spam
# P(Spam|message): 5.9096926849614685e-31
# P(Ham|message): 6.390948299182817e-31
# Label: Ham
# P(Spam|message): 6.612244841975424e-63
# P(Ham|message): 1.9429980994825394e-57
# Label: Ham
# P(Spam|message): 1.9224637309679756e-37
# P(Ham|message): 1.673171627764064e-32
# Label: Ham
# P(Spam|message): 1.845834795550054e-164
# P(Ham|message): 4.1144551878651945e-161
# Label: Ham
# P(Spam|message): 9.237178468907361e-49
# P(Ham|message): 3.315784751436691e-48
# Label: Ham
# P(Spam|message): 1.457700820703971e-55
# P(Ham|message): 5.219813957296917e-51
# Label: Ham
# P(Spam|message): 5.3856629447787884e-161
# P(Ham|message): 1.064229639776172e-180
# Label: Spam
# P(Spam|message): 1.0041068846379426e-35
# P(Ham|message): 5.569106602880482e-34
# Label: Ham
# P(Spam|message): 4.057588533093623e-219
# P(Ham|message): 3.2898532941201627e-203
# Label: Ham
# P(Spam|message): 7.514177786510408e-171
# P(Ham|message): 1.297862240067065e-156
# Label: Ham
# P(Spam|message): 3.332098368310241e-146
# P(Ham|message): 5.7367388368612544e-142
# Label: Ham
# P(Spam|message): 1.669211175475128e-36
# P(Ham|message): 4.577683229620441e-35
# Label: Ham
# P(Spam|message): 7.130592747590312e-39
# P(Ham|message): 1.0674622449095349e-33
# Label: Ham
# P(Spam|message): 6.7738001984828675e-71
# P(Ham|message): 4.536789700098143e-71
# Label: Spam
# P(Spam|message): 1.3197141487400126e-60
# P(Ham|message): 1.3987605821575252e-54
# Label: Ham
# P(Spam|message): 5.366401269591766e-71
# P(Ham|message): 6.231659232857786e-65
# Label: Ham
# P(Spam|message): 2.6964724339769474e-56
# P(Ham|message): 1.1088019780984762e-53
# Label: Ham
# P(Spam|message): 6.404344276424895e-189
# P(Ham|message): 1.4477676400308493e-220
# Label: Spam
# P(Spam|message): 2.4544503516337324e-22
# P(Ham|message): 5.0870232212643974e-20
# Label: Ham
# P(Spam|message): 3.425480829724757e-39
# P(Ham|message): 8.843577631429844e-37
# Label: Ham
# P(Spam|message): 1.2822313295679925e-150
# P(Ham|message): 3.9262119071777184e-141
# Label: Ham
# P(Spam|message): 3.6007350766524176e-54
# P(Ham|message): 8.56382977615861e-50
# Label: Ham
# P(Spam|message): 4.55159404372621e-72
# P(Ham|message): 9.529976288328967e-67
# Label: Ham
# P(Spam|message): 7.005775325817832e-83
# P(Ham|message): 4.167180808696549e-80
# Label: Ham
# P(Spam|message): 1.8936769626468322e-75
# P(Ham|message): 1.3973854727376789e-70
# Label: Ham
# P(Spam|message): 1.0911792276281269e-113
# P(Ham|message): 8.014625530815344e-114
# Label: Spam
# P(Spam|message): 4.6959097190280665e-112
# P(Ham|message): 1.6377783458184747e-104
# Label: Ham
# P(Spam|message): 7.329148362542667e-25
# P(Ham|message): 1.5980543583826545e-21
# Label: Ham
# P(Spam|message): 1.1647821950494678e-71
# P(Ham|message): 2.0635248295631216e-66
# Label: Ham
# P(Spam|message): 4.168624501505644e-158
# P(Ham|message): 2.4327356398661003e-146
# Label: Ham
# P(Spam|message): 3.3310480463872e-81
# P(Ham|message): 7.882169093490133e-79
# Label: Ham
# P(Spam|message): 5.4737292949836015e-71
# P(Ham|message): 9.799257336686489e-65
# Label: Ham
# P(Spam|message): 5.146762729568627e-89
# P(Ham|message): 9.964447766924876e-79
# Label: Ham
# P(Spam|message): 3.2080375659842513e-173
# P(Ham|message): 2.020237867775916e-158
# Label: Ham
# P(Spam|message): 1.0442016498769556e-48
# P(Ham|message): 2.463515684861153e-46
# Label: Ham
# P(Spam|message): 4.139342301643347e-176
# P(Ham|message): 1.7084506533787684e-198
# Label: Spam
# P(Spam|message): 4.7362872800540854e-147
# P(Ham|message): 2.889952772604925e-147
# Label: Spam
# P(Spam|message): 3.33424295642441e-43
# P(Ham|message): 7.599931785447782e-41
# Label: Ham
# P(Spam|message): 5.262749606564064e-77
# P(Ham|message): 4.4217414095652057e-69
# Label: Ham
# P(Spam|message): 1.4744445451577794e-292
# P(Ham|message): 2.8642269195252726e-280
# Label: Ham
# P(Spam|message): 4.6836725242118865e-32
# P(Ham|message): 4.309598707061585e-28
# Label: Ham
# P(Spam|message): 5.664859793918969e-36
# P(Ham|message): 5.965905545012197e-33
# Label: Ham
# P(Spam|message): 3.274676658829365e-138
# P(Ham|message): 1.8061956088482838e-128
# Label: Ham
# P(Spam|message): 1.9976016636511466e-94
# P(Ham|message): 1.7266446998183248e-90
# Label: Ham
# P(Spam|message): 8.326206194774903e-107
# P(Ham|message): 2.600482089357944e-100
# Label: Ham
# P(Spam|message): 1.288686686702073e-75
# P(Ham|message): 5.493002725992875e-71
# Label: Ham
# P(Spam|message): 6.433821299190444e-106
# P(Ham|message): 3.5452389350297153e-99
# Label: Ham
# P(Spam|message): 2.6418793450200265e-67
# P(Ham|message): 2.8036896889326564e-61
# Label: Ham
# P(Spam|message): 1.5113440763863956e-95
# P(Ham|message): 2.2337671133001905e-88
# Label: Ham
# P(Spam|message): 1.1583152678591224e-167
# P(Ham|message): 1.0674929382312138e-159
# Label: Ham
# P(Spam|message): 5.428665114239652e-150
# P(Ham|message): 1.6957528324582743e-135
# Label: Ham
# P(Spam|message): 3.481467291323211e-208
# P(Ham|message): 4.824544335280365e-192
# Label: Ham
# P(Spam|message): 3.6751145888726387e-75
# P(Ham|message): 5.594076775418765e-72
# Label: Ham
# P(Spam|message): 7.574768350557243e-155
# P(Ham|message): 9.027429555837546e-180
# Label: Spam
# P(Spam|message): 5.706495441917998e-72
# P(Ham|message): 2.346369611068595e-67
# Label: Ham
# P(Spam|message): 5.0462271967000715e-211
# P(Ham|message): 6.326498427181377e-200
# Label: Ham
# P(Spam|message): 5.636854769236024e-47
# P(Ham|message): 9.266271614967972e-44
# Label: Ham
# P(Spam|message): 6.451766550744341e-80
# P(Ham|message): 2.813268571898398e-75
# Label: Ham
# P(Spam|message): 2.192430983588541e-68
# P(Ham|message): 1.0920275805559056e-65
# Label: Ham
# P(Spam|message): 1.7003099919508507e-47
# P(Ham|message): 5.767898140036508e-45
# Label: Ham
# P(Spam|message): 7.246365302742019e-159
# P(Ham|message): 3.4451203415333774e-151
# Label: Ham
# P(Spam|message): 1.1666992149878656e-59
# P(Ham|message): 1.0736545659716706e-56
# Label: Ham
# P(Spam|message): 1.0242102319515723e-53
# P(Ham|message): 1.83268931207139e-52
# Label: Ham
# P(Spam|message): 1.398827232035166e-52
# P(Ham|message): 3.2702676408264906e-47
# Label: Ham
# P(Spam|message): 1.5841833537775498e-32
# P(Ham|message): 4.949145089283625e-30
# Label: Ham
# P(Spam|message): 1.5405094987925802e-16
# P(Ham|message): 2.1367577000799074e-16
# Label: Ham
# P(Spam|message): 1.1284895681865816e-29
# P(Ham|message): 4.8996449369449355e-27
# Label: Ham
# P(Spam|message): 1.1383551903343649e-09
# P(Ham|message): 2.913948939541602e-08
# Label: Ham
# P(Spam|message): 2.319656575102605e-199
# P(Ham|message): 4.980450709946384e-218
# Label: Spam
# P(Spam|message): 9.50978725585492e-38
# P(Ham|message): 4.464618469087387e-37
# Label: Ham
# P(Spam|message): 1.7518914393777022e-222
# P(Ham|message): 3.5234593141026417e-261
# Label: Spam
# P(Spam|message): 3.519731763307851e-155
# P(Ham|message): 7.179980000437521e-143
# Label: Ham
# P(Spam|message): 1.3140660235928168e-190
# P(Ham|message): 3.572684619853874e-203
# Label: Spam
# P(Spam|message): 1.4055659477689501e-210
# P(Ham|message): 1.1588834075968843e-234
# Label: Spam
# P(Spam|message): 4.8140921837268134e-17
# P(Ham|message): 1.2802231134478761e-13
# Label: Ham
# P(Spam|message): 5.445876677434296e-139
# P(Ham|message): 2.0911959652118244e-130
# Label: Ham
# P(Spam|message): 5.02962677957065e-51
# P(Ham|message): 7.635174301429292e-45
# Label: Ham
# P(Spam|message): 1.2083469769217556e-215
# P(Ham|message): 3.189895391871395e-212
# Label: Ham
# P(Spam|message): 2.6275937973045787e-200
# P(Ham|message): 1.3480714214630497e-188
# Label: Ham
# P(Spam|message): 3.111315302198572e-36
# P(Ham|message): 5.449005659515206e-33
# Label: Ham
# P(Spam|message): 5.995961644350214e-34
# P(Ham|message): 6.515146195053671e-32
# Label: Ham
# P(Spam|message): 4.549803637814914e-200
# P(Ham|message): 7.067344880885168e-205
# Label: Spam
# P(Spam|message): 4.344114926726165e-77
# P(Ham|message): 7.79692373258306e-77
# Label: Ham
# P(Spam|message): 3.333889926472681e-57
# P(Ham|message): 3.6028597918007554e-51
# Label: Ham
# P(Spam|message): 1.5715225837109885e-153
# P(Ham|message): 8.000091362066416e-149
# Label: Ham
# P(Spam|message): 2.2148140629167355e-77
# P(Ham|message): 4.600463183864182e-73
# Label: Ham
# P(Spam|message): 9.341404259051686e-127
# P(Ham|message): 3.883208705104055e-122
# Label: Ham
# P(Spam|message): 1.172164704580432e-134
# P(Ham|message): 2.0533948618678485e-128
# Label: Ham
# P(Spam|message): 2.120844449134099e-181
# P(Ham|message): 3.063918457114832e-200
# Label: Spam
# P(Spam|message): 4.584488870757987e-28
# P(Ham|message): 5.3645457860031466e-27
# Label: Ham
# P(Spam|message): 3.28368319666e-89
# P(Ham|message): 1.152061382648895e-81
# Label: Ham
# P(Spam|message): 1.9680070926285298e-115
# P(Ham|message): 4.05191885789088e-106
# Label: Ham
# P(Spam|message): 8.685880758050055e-45
# P(Ham|message): 2.5256707194467544e-40
# Label: Ham
# P(Spam|message): 1.6946865807150384e-103
# P(Ham|message): 1.0436660132825847e-95
# Label: Ham
# P(Spam|message): 3.8861195215100037e-88
# P(Ham|message): 5.767822138326551e-81
# Label: Ham
# P(Spam|message): 1.9197169931707045e-196
# P(Ham|message): 3.588849799141066e-222
# Label: Spam
# P(Spam|message): 4.760971934684862e-54
# P(Ham|message): 5.076992862193532e-47
# Label: Ham
# P(Spam|message): 1.427008865155541e-169
# P(Ham|message): 5.601376550336028e-156
# Label: Ham
# P(Spam|message): 7.54861060097409e-140
# P(Ham|message): 3.3488085557187735e-133
# Label: Ham
# P(Spam|message): 1.6994579381756906e-35
# P(Ham|message): 3.450135817023597e-33
# Label: Ham
# P(Spam|message): 3.3346115244689317e-104
# P(Ham|message): 5.011253991982549e-93
# Label: Ham
# P(Spam|message): 1.9034338683750194e-63
# P(Ham|message): 8.01456572152903e-60
# Label: Ham
# P(Spam|message): 2.3696602485772943e-20
# P(Ham|message): 1.0389790730930634e-21
# Label: Spam
# P(Spam|message): 2.0338042597536772e-218
# P(Ham|message): 3.019798706891166e-203
# Label: Ham
# P(Spam|message): 1.078220114619807e-51
# P(Ham|message): 5.116343520776362e-49
# Label: Ham
# P(Spam|message): 1.995034567893907e-189
# P(Ham|message): 8.599303062254777e-201
# Label: Spam
# P(Spam|message): 3.1717159228797907e-106
# P(Ham|message): 1.7813139000589724e-99
# Label: Ham
# P(Spam|message): 2.289628765684024e-67
# P(Ham|message): 7.431971524645649e-63
# Label: Ham
# P(Spam|message): 2.865305544223742e-29
# P(Ham|message): 9.186007619415673e-28
# Label: Ham
# P(Spam|message): 1.459624305795435e-94
# P(Ham|message): 2.991299086178821e-91
# Label: Ham
# P(Spam|message): 2.97881572539876e-29
# P(Ham|message): 1.3638347393165663e-26
# Label: Ham
# P(Spam|message): 0.0
# P(Ham|message): 0.0
# Equal proabilities, have a human classify this!
# P(Spam|message): 5.553583051054128e-45
# P(Ham|message): 3.0686951724756505e-41
# Label: Ham
# P(Spam|message): 2.621541451319968e-40
# P(Ham|message): 4.396112331976703e-37
# Label: Ham
# P(Spam|message): 1.033935948400595e-36
# P(Ham|message): 6.510168475916629e-32
# Label: Ham
# P(Spam|message): 5.691775951671824e-09
# P(Ham|message): 4.526334019421289e-07
# Label: Ham
# P(Spam|message): 6.431798887443795e-118
# P(Ham|message): 1.769713001734066e-113
# Label: Ham
# P(Spam|message): 4.101107483855356e-43
# P(Ham|message): 1.681470835596469e-38
# Label: Ham
# P(Spam|message): 1.7783420630346108e-137
# P(Ham|message): 2.460122321097964e-131
# Label: Ham
# P(Spam|message): 3.760317224190998e-195
# P(Ham|message): 1.503364888723057e-185
# Label: Ham
# P(Spam|message): 2.6273437963988882e-36
# P(Ham|message): 2.0074180405294874e-37
# Label: Spam
# P(Spam|message): 1.0051734029057247e-47
# P(Ham|message): 1.4498833782556528e-40
# Label: Ham
# P(Spam|message): 1.7503653305617616e-50
# P(Ham|message): 9.060851927123742e-51
# Label: Spam
# P(Spam|message): 4.4736247469722176e-42
# P(Ham|message): 5.020429937736309e-38
# Label: Ham
# P(Spam|message): 6.56096135322969e-176
# P(Ham|message): 5.562158368536872e-160
# Label: Ham
# P(Spam|message): 1.6886913168816172e-44
# P(Ham|message): 8.108748329750918e-39
# Label: Ham
# P(Spam|message): 2.0412667169961343e-52
# P(Ham|message): 9.192830401830406e-47
# Label: Ham
# P(Spam|message): 1.4560355658565561e-102
# P(Ham|message): 6.105472509312037e-98
# Label: Ham
# P(Spam|message): 9.308234187569444e-55
# P(Ham|message): 2.0335040169028693e-53
# Label: Ham
# P(Spam|message): 1.2937476465464044e-76
# P(Ham|message): 1.3757559140660547e-70
# Label: Ham
# P(Spam|message): 2.0695548331637297e-191
# P(Ham|message): 8.760903376078201e-181
# Label: Ham
# P(Spam|message): 1.7724324997983817e-58
# P(Ham|message): 3.5060189294071923e-56
# Label: Ham
# P(Spam|message): 4.27918660521831e-278
# P(Ham|message): 5.781058954059317e-257
# Label: Ham
# P(Spam|message): 5.463413084028762e-46
# P(Ham|message): 1.1017159172669773e-44
# Label: Ham
# P(Spam|message): 6.90312016264007e-61
# P(Ham|message): 2.19150207796612e-56
# Label: Ham
# P(Spam|message): 4.2650879233322707e-166
# P(Ham|message): 1.0553200829883831e-190
# Label: Spam
# P(Spam|message): 1.930855981498319e-66
# P(Ham|message): 4.735573173694467e-64
# Label: Ham
# P(Spam|message): 4.5974833754252594e-125
# P(Ham|message): 1.2528198610686756e-129
# Label: Spam
# P(Spam|message): 7.244437724974525e-47
# P(Ham|message): 3.0446103556568093e-45
# Label: Ham
# P(Spam|message): 1.9687980908517145e-108
# P(Ham|message): 2.749473983552868e-103
# Label: Ham
# P(Spam|message): 9.888168439794127e-91
# P(Ham|message): 1.283206388744585e-88
# Label: Ham
# P(Spam|message): 6.83254470490807e-118
# P(Ham|message): 2.089413520000513e-116
# Label: Ham
# P(Spam|message): 1.760421579905152e-280
# P(Ham|message): 1.0162248192761231e-268
# Label: Ham
# P(Spam|message): 4.788241696981742e-207
# P(Ham|message): 3.712456834494937e-232
# Label: Spam
# P(Spam|message): 4.739599810344897e-272
# P(Ham|message): 4.853010351847977e-263
# Label: Ham
# P(Spam|message): 2.0107310833440196e-148
# P(Ham|message): 9.523255543421231e-143
# Label: Ham
# P(Spam|message): 6.426408622577268e-45
# P(Ham|message): 2.400795755213748e-41
# Label: Ham
# P(Spam|message): 8.539017700174422e-68
# P(Ham|message): 4.9000630972244295e-61
# Label: Ham
# P(Spam|message): 5.2429263165502654e-129
# P(Ham|message): 3.426771661073955e-120
# Label: Ham
# P(Spam|message): 1.864207254271977e-39
# P(Ham|message): 5.658533530137666e-40
# Label: Spam
# P(Spam|message): 5.3252531213081375e-297
# P(Ham|message): 1.765585261465959e-282
# Label: Ham
# P(Spam|message): 1.7091204962695102e-102
# P(Ham|message): 4.698033432456887e-95
# Label: Ham
# P(Spam|message): 1.1290105183684661e-38
# P(Ham|message): 4.308695091697829e-34
# Label: Ham
# P(Spam|message): 2.4810281716757714e-79
# P(Ham|message): 1.6618618224165256e-72
# Label: Ham
# P(Spam|message): 1.6041563062938927e-100
# P(Ham|message): 6.825423317763678e-90
# Label: Ham
# P(Spam|message): 6.722057245588968e-85
# P(Ham|message): 1.3286263987433358e-81
# Label: Ham
# P(Spam|message): 1.8184223241070573e-35
# P(Ham|message): 4.662977296572098e-34
# Label: Ham
# P(Spam|message): 2.079756218047174e-38
# P(Ham|message): 2.6090468207010557e-36
# Label: Ham
# P(Spam|message): 2.2751397165025843e-130
# P(Ham|message): 3.833780584685831e-126
# Label: Ham
# P(Spam|message): 3.513101749419027e-173
# P(Ham|message): 8.257589360096148e-194
# Label: Spam
# P(Spam|message): 1.5009771779902912e-83
# P(Ham|message): 1.6790394803924242e-76
# Label: Ham
# P(Spam|message): 2.0680495721247485e-177
# P(Ham|message): 4.50543068729818e-186
# Label: Spam
# P(Spam|message): 5.8894549726471125e-87
# P(Ham|message): 3.291598130520436e-78
# Label: Ham
# P(Spam|message): 8.84514713181121e-184
# P(Ham|message): 1.2229851843256626e-171
# Label: Ham
# P(Spam|message): 1.6641848233741585e-113
# P(Ham|message): 3.244623410900946e-105
# Label: Ham
# P(Spam|message): 3.300679053213008e-74
# P(Ham|message): 6.077011531826103e-71
# Label: Ham
# P(Spam|message): 3.3197635576097357e-98
# P(Ham|message): 1.2634452345701687e-94
# Label: Ham
# P(Spam|message): 1.75104287323923e-75
# P(Ham|message): 1.0433176698876673e-70
# Label: Ham
# P(Spam|message): 3.968990454707752e-35
# P(Ham|message): 2.1247945203523544e-33
# Label: Ham
# P(Spam|message): 9.255509386372222e-36
# P(Ham|message): 6.291318574740133e-36
# Label: Spam
# P(Spam|message): 5.24200808816263e-66
# P(Ham|message): 4.069126558242959e-58
# Label: Ham
# P(Spam|message): 7.207398870985458e-58
# P(Ham|message): 1.317245121458264e-55
# Label: Ham
# P(Spam|message): 1.625180930388292e-37
# P(Ham|message): 4.981052581512054e-34
# Label: Ham
# P(Spam|message): 1.0904144063827366e-22
# P(Ham|message): 3.721295312107207e-22
# Label: Ham
# P(Spam|message): 4.132652227245782e-33
# P(Ham|message): 8.843833149235342e-31
# Label: Ham
# P(Spam|message): 7.689854923871904e-40
# P(Ham|message): 1.3042817191519776e-35
# Label: Ham
# P(Spam|message): 5.200282649683086e-107
# P(Ham|message): 5.060490877327148e-97
# Label: Ham
# P(Spam|message): 1.7161505108197435e-26
# P(Ham|message): 2.212513852694463e-25
# Label: Ham
# P(Spam|message): 1.6484533529505217e-60
# P(Ham|message): 1.3058220412647175e-56
# Label: Ham
# P(Spam|message): 8.373535500711675e-148
# P(Ham|message): 1.144163090751494e-143
# Label: Ham
# P(Spam|message): 2.0492234381234862e-107
# P(Ham|message): 1.7679468214224194e-98
# Label: Ham
# P(Spam|message): 6.038834290806586e-59
# P(Ham|message): 3.2695767041795794e-60
# Label: Spam
# P(Spam|message): 7.680414587525617e-167
# P(Ham|message): 2.358235507512824e-195
# Label: Spam
# P(Spam|message): 3.8848362948670882e-205
# P(Ham|message): 3.764941326099389e-198
# Label: Ham
# P(Spam|message): 1.6514750624819197e-47
# P(Ham|message): 3.698095171074253e-43
# Label: Ham
# P(Spam|message): 8.141819654098796e-58
# P(Ham|message): 2.2986129151073736e-57
# Label: Ham
# P(Spam|message): 4.770320358141802e-180
# P(Ham|message): 5.85050612419759e-170
# Label: Ham
# P(Spam|message): 7.379040034970517e-42
# P(Ham|message): 4.844490573774248e-41
# Label: Ham
# P(Spam|message): 6.515164809499694e-57
# P(Ham|message): 2.391125573700205e-52
# Label: Ham
# P(Spam|message): 1.0081149747319546e-62
# P(Ham|message): 4.8658951782981164e-58
# Label: Ham
# P(Spam|message): 2.3520378860796113e-121
# P(Ham|message): 2.745208973813045e-134
# Label: Spam
# P(Spam|message): 7.578645165366344e-272
# P(Ham|message): 1.731333026577771e-254
# Label: Ham
# P(Spam|message): 9.37305954209818e-198
# P(Ham|message): 1.690793750457906e-188
# Label: Ham
# P(Spam|message): 1.469402292296528e-118
# P(Ham|message): 1.1214129814023234e-114
# Label: Ham
# P(Spam|message): 9.878552487300961e-192
# P(Ham|message): 2.0061040857366948e-182
# Label: Ham
# P(Spam|message): 6.859352048038041e-64
# P(Ham|message): 5.79455116216899e-59
# Label: Ham
# P(Spam|message): 8.190005292404317e-53
# P(Ham|message): 4.59200738737113e-52
# Label: Ham
# P(Spam|message): 2.902030414887244e-212
# P(Ham|message): 6.094742174800721e-197
# Label: Ham
# P(Spam|message): 1.7137061101745948e-86
# P(Ham|message): 6.746575091507866e-78
# Label: Ham
# P(Spam|message): 4.25086779882577e-56
# P(Ham|message): 2.2321718301215033e-49
# Label: Ham
# P(Spam|message): 5.7797290083375005e-65
# P(Ham|message): 1.5865370187074369e-62
# Label: Ham
# P(Spam|message): 9.568e-320
# P(Ham|message): 4.849036295337746e-304
# Label: Ham
# P(Spam|message): 7.428550088235485e-192
# P(Ham|message): 9.141340782566785e-217
# Label: Spam
# P(Spam|message): 3.088487298257592e-185
# P(Ham|message): 3.419345885664787e-198
# Label: Spam
# P(Spam|message): 1.0024692668371467e-229
# P(Ham|message): 7.885193327766826e-220
# Label: Ham
# P(Spam|message): 9.278681525374467e-231
# P(Ham|message): 5.986381675478759e-216
# Label: Ham
# P(Spam|message): 2.1874644108471508e-67
# P(Ham|message): 3.274261879722416e-62
# Label: Ham
# P(Spam|message): 5.691775951671824e-09
# P(Ham|message): 4.526334019421289e-07
# Label: Ham
# P(Spam|message): 2.6914492233551653e-39
# P(Ham|message): 1.6290894357393835e-37
# Label: Ham
# P(Spam|message): 3.900489340063985e-66
# P(Ham|message): 6.4551183952805425e-62
# Label: Ham
# P(Spam|message): 1.0232149861073238e-58
# P(Ham|message): 1.153016220969009e-54
# Label: Ham
# P(Spam|message): 4.7822137838369995e-98
# P(Ham|message): 6.937144383646797e-89
# Label: Ham
# P(Spam|message): 3.369718386546681e-66
# P(Ham|message): 1.5819323411241574e-61
# Label: Ham
# P(Spam|message): 2.1980679055926217e-82
# P(Ham|message): 3.478380460119472e-81
# Label: Ham
# P(Spam|message): 6.838896135169695e-55
# P(Ham|message): 1.8528231912472502e-50
# Label: Ham
# P(Spam|message): 4.056170319960747e-44
# P(Ham|message): 6.070014698890579e-41
# Label: Ham
# P(Spam|message): 4.0291799356298115e-66
# P(Ham|message): 1.6459782465901685e-66
# Label: Spam
# P(Spam|message): 4.444026734583819e-84
# P(Ham|message): 1.3450246980432134e-79
# Label: Ham
# P(Spam|message): 3.2873739653463514e-130
# P(Ham|message): 1.6185439633678204e-123
# Label: Ham
# P(Spam|message): 1.5077601043585867e-46
# P(Ham|message): 7.795394582105013e-41
# Label: Ham
# P(Spam|message): 1.2452324626585033e-43
# P(Ham|message): 1.2281415114572805e-40
# Label: Ham
# P(Spam|message): 5.1529018767145285e-37
# P(Ham|message): 2.0250621530561223e-34
# Label: Ham
# P(Spam|message): 1.5439542017345643e-56
# P(Ham|message): 1.4715813926804978e-54
# Label: Ham
# P(Spam|message): 1.9740965172253015e-156
# P(Ham|message): 2.292718621317166e-144
# Label: Ham
# P(Spam|message): 6.008659786711799e-175
# P(Ham|message): 3.930817534495696e-167
# Label: Ham
# P(Spam|message): 3.486757879003176e-75
# P(Ham|message): 5.476752117225646e-71
# Label: Ham
# P(Spam|message): 8.630969244174523e-213
# P(Ham|message): 1.2982047926808748e-200
# Label: Ham
# P(Spam|message): 1.3183114160039835e-199
# P(Ham|message): 3.656529628108345e-191
# Label: Ham
# P(Spam|message): 1.9023513231154687e-78
# P(Ham|message): 4.6473307399752325e-76
# Label: Ham
# P(Spam|message): 2.6261633347092797e-45
# P(Ham|message): 9.420872734563082e-45
# Label: Ham
# P(Spam|message): 4.511743782352655e-48
# P(Ham|message): 1.5327031438771315e-45
# Label: Ham
# P(Spam|message): 5.776404739129478e-153
# P(Ham|message): 4.1609194731346837e-163
# Label: Spam
# P(Spam|message): 2.766958366661153e-59
# P(Ham|message): 3.411543415553069e-55
# Label: Ham
# P(Spam|message): 9.50311534452024e-162
# P(Ham|message): 3.1841973012289636e-156
# Label: Ham
# P(Spam|message): 2.3957140462039103e-54
# P(Ham|message): 2.8712921344687945e-51
# Label: Ham
# P(Spam|message): 7.890689934949442e-63
# P(Ham|message): 3.982980773053658e-58
# Label: Ham
# P(Spam|message): 2.0873480252812725e-99
# P(Ham|message): 4.563836749969193e-94
# Label: Ham
# P(Spam|message): 1.1679376961879592e-95
# P(Ham|message): 3.203715538856522e-92
# Label: Ham
# P(Spam|message): 8.143498180602963e-25
# P(Ham|message): 5.661231930776732e-22
# Label: Ham
# P(Spam|message): 2.7849155616451966e-61
# P(Ham|message): 1.1036407139591718e-58
# Label: Ham
# P(Spam|message): 4.149334565376164e-92
# P(Ham|message): 2.626328619484876e-85
# Label: Ham
# P(Spam|message): 7.32526568632096e-78
# P(Ham|message): 1.366438150059811e-71
# Label: Ham
# P(Spam|message): 4.487947664463834e-48
# P(Ham|message): 1.652593118833025e-45
# Label: Ham
# P(Spam|message): 4.3342181478223535e-54
# P(Ham|message): 1.1344008723767306e-50
# Label: Ham
# P(Spam|message): 5.191956346308866e-193
# P(Ham|message): 5.7181190544862075e-182
# Label: Ham
# P(Spam|message): 1.3162468344694073e-36
# P(Ham|message): 7.209414550914837e-34
# Label: Ham
# P(Spam|message): 8.0219168410391e-39
# P(Ham|message): 1.4510049523781307e-34
# Label: Ham
# P(Spam|message): 1.0951203714228475e-73
# P(Ham|message): 1.5997734750110572e-66
# Label: Ham
# P(Spam|message): 1.620356948737096e-120
# P(Ham|message): 2.088668077489373e-115
# Label: Ham
# P(Spam|message): 6.260325748903002e-132
# P(Ham|message): 1.8014046042345712e-126
# Label: Ham
# P(Spam|message): 1.7064653541410824e-100
# P(Ham|message): 9.372989126375526e-97
# Label: Ham
# P(Spam|message): 2.690593919961763e-204
# P(Ham|message): 2.494678394181803e-228
# Label: Spam
# P(Spam|message): 3.6008883130402e-89
# P(Ham|message): 1.606035654497707e-83
# Label: Ham
# P(Spam|message): 2.708412362375809e-108
# P(Ham|message): 6.420636449336725e-101
# Label: Ham
# P(Spam|message): 6.313681932704157e-175
# P(Ham|message): 5.051274385653404e-166
# Label: Ham
# P(Spam|message): 1.575318487835175e-140
# P(Ham|message): 1.269964294308097e-128
# Label: Ham
# P(Spam|message): 4.023594015061948e-61
# P(Ham|message): 1.4843680846300273e-66
# Label: Spam
# P(Spam|message): 3.367982561778673e-170
# P(Ham|message): 7.497901385744245e-190
# Label: Spam
# P(Spam|message): 5.792642456575394e-136
# P(Ham|message): 2.744909175345385e-128
# Label: Ham
# P(Spam|message): 2.2796320450565654e-54
# P(Ham|message): 7.570542918276705e-48
# Label: Ham
# P(Spam|message): 2.479591336347469e-32
# P(Ham|message): 4.110839885356779e-30
# Label: Ham
# P(Spam|message): 8.095917225833484e-236
# P(Ham|message): 5.476302356151997e-248
# Label: Spam
# P(Spam|message): 1.1695839317198875e-164
# P(Ham|message): 1.948311891070628e-182
# Label: Spam
# P(Spam|message): 4.1007179802076515e-88
# P(Ham|message): 2.266425776201231e-81
# Label: Ham
# P(Spam|message): 3.1725331726431154e-58
# P(Ham|message): 7.401451011079675e-56
# Label: Ham
# P(Spam|message): 1.0950339450454014e-77
# P(Ham|message): 6.451611069696236e-74
# Label: Ham
# P(Spam|message): 2.3044704490575473e-51
# P(Ham|message): 5.2546597471095394e-46
# Label: Ham
# P(Spam|message): 7.900186584421996e-260
# P(Ham|message): 3.2237835455800534e-241
# Label: Ham
# P(Spam|message): 3.5579975653277393e-57
# P(Ham|message): 2.1099425190270127e-51
# Label: Ham
# P(Spam|message): 7.54240642084046e-50
# P(Ham|message): 8.611620662661258e-47
# Label: Ham
# P(Spam|message): 3.865755722233011e-55
# P(Ham|message): 2.8056127272050883e-53
# Label: Ham
# P(Spam|message): 7.311431236091943e-169
# P(Ham|message): 4.0099479103144234e-179
# Label: Spam
# P(Spam|message): 2.4430494541808885e-25
# P(Ham|message): 5.550227383114442e-23
# Label: Ham
# P(Spam|message): 3.581631930279678e-31
# P(Ham|message): 2.279145981178611e-29
# Label: Ham
# P(Spam|message): 9.852712730970481e-70
# P(Ham|message): 3.435764758443073e-63
# Label: Ham
# P(Spam|message): 6.497927410671759e-35
# P(Ham|message): 2.4930357083214083e-32
# Label: Ham
# P(Spam|message): 1.0094779023762052e-68
# P(Ham|message): 3.5307123420386946e-63
# Label: Ham
# P(Spam|message): 4.138945350088544e-117
# P(Ham|message): 7.292471490463662e-110
# Label: Ham
# P(Spam|message): 4.749298992549565e-92
# P(Ham|message): 4.7648179916800444e-87
# Label: Ham
# P(Spam|message): 8.417944457196776e-66
# P(Ham|message): 3.804238533811628e-61
# Label: Ham
# P(Spam|message): 7.130592747590311e-39
# P(Ham|message): 5.330373152163549e-35
# Label: Ham
# P(Spam|message): 1.7809664773315697e-29
# P(Ham|message): 2.9149843609062836e-28
# Label: Ham
# P(Spam|message): 3.0207638368154554e-134
# P(Ham|message): 1.448423411579778e-128
# Label: Ham
# P(Spam|message): 3.394168498690382e-150
# P(Ham|message): 1.0614671730725045e-141
# Label: Ham
# P(Spam|message): 5.315303376073089e-213
# P(Ham|message): 1.7127920875486473e-217
# Label: Spam
# P(Spam|message): 2.219453057431055e-215
# P(Ham|message): 2.143096124386228e-207
# Label: Ham
# P(Spam|message): 9.564931307381455e-102
# P(Ham|message): 2.5354130068114987e-95
# Label: Ham
# P(Spam|message): 3.6524629367023484e-49
# P(Ham|message): 7.607738281145486e-47
# Label: Ham
# P(Spam|message): 1.033935948400595e-36
# P(Ham|message): 6.510168475916629e-32
# Label: Ham
# P(Spam|message): 3.6273566293577185e-40
# P(Ham|message): 9.89569503346099e-38
# Label: Ham
# P(Spam|message): 8.523569736216112e-112
# P(Ham|message): 5.4047547661956355e-109
# Label: Ham
# P(Spam|message): 1.2110129895079142e-55
# P(Ham|message): 8.846468005355487e-50
# Label: Ham
# P(Spam|message): 8.899557046188255e-91
# P(Ham|message): 3.372542314872848e-85
# Label: Ham
# P(Spam|message): 2.4014081603007443e-99
# P(Ham|message): 3.6560074035222113e-93
# Label: Ham
# P(Spam|message): 6.564995450605296e-120
# P(Ham|message): 2.031819923761389e-114
# Label: Ham
# P(Spam|message): 2.1771647739041234e-155
# P(Ham|message): 4.6177679364895195e-150
# Label: Ham
# P(Spam|message): 1.374702238270847e-62
# P(Ham|message): 1.3001540961560668e-59
# Label: Ham
# P(Spam|message): 3.885871638794309e-73
# P(Ham|message): 9.244680779375037e-68
# Label: Ham
# P(Spam|message): 7.357646695527163e-221
# P(Ham|message): 1.58620339685152e-212
# Label: Ham
# P(Spam|message): 9.413709349880671e-163
# P(Ham|message): 5.893682362005239e-170
# Label: Spam
# P(Spam|message): 8.563345385929902e-68
# P(Ham|message): 1.679893660016265e-62
# Label: Ham
# P(Spam|message): 4.982660241718138e-176
# P(Ham|message): 5.825604996111926e-198
# Label: Spam
# P(Spam|message): 1.2110129895079142e-55
# P(Ham|message): 8.846468005355487e-50
# Label: Ham
# P(Spam|message): 7.816416038538029e-108
# P(Ham|message): 2.1237889905064354e-103
# Label: Ham
# P(Spam|message): 5.429908425673093e-86
# P(Ham|message): 5.013425055591379e-79
# Label: Ham
# P(Spam|message): 0.0
# P(Ham|message): 0.0
# Equal proabilities, have a human classify this!
# P(Spam|message): 3.247047302590055e-192
# P(Ham|message): 6.3421405126614814e-204
# Label: Spam
# P(Spam|message): 8.957847998663258e-25
# P(Ham|message): 1.3156094537752751e-23
# Label: Ham
# P(Spam|message): 3.1271033013515376e-22
# P(Ham|message): 1.0300282302021994e-20
# Label: Ham
# P(Spam|message): 2.554468145575399e-101
# P(Ham|message): 6.129170961931454e-92
# Label: Ham
# P(Spam|message): 3.50288991314342e-97
# P(Ham|message): 2.4957503051778122e-98
# Label: Spam
# P(Spam|message): 9.63257672004556e-44
# P(Ham|message): 1.243632122712611e-39
# Label: Ham
# P(Spam|message): 4.499588120368189e-165
# P(Ham|message): 1.0576252808013424e-152
# Label: Ham
# P(Spam|message): 2.3302590678399713e-40
# P(Ham|message): 1.1378476354600833e-37
# Label: Ham
# P(Spam|message): 1.4083452422671058e-71
# P(Ham|message): 6.509388295964491e-66
# Label: Ham
# P(Spam|message): 3.698609248707827e-42
# P(Ham|message): 9.574153698551828e-39
# Label: Ham
# P(Spam|message): 4.021444224122772e-189
# P(Ham|message): 1.4362103126730875e-218
# Label: Spam
# P(Spam|message): 5.032509953861915e-59
# P(Ham|message): 3.99090731969287e-55
# Label: Ham
# P(Spam|message): 5.362584644941802e-154
# P(Ham|message): 7.78194159036956e-158
# Label: Spam
# P(Spam|message): 2.547495250259931e-55
# P(Ham|message): 6.738605737336175e-51
# Label: Ham
# P(Spam|message): 4.1608898998393526e-178
# P(Ham|message): 2.3991102148434836e-172
# Label: Ham
# P(Spam|message): 0.0
# P(Ham|message): 0.0
# Equal proabilities, have a human classify this!
# P(Spam|message): 5.858564257674939e-155
# P(Ham|message): 6.673209570775173e-151
# Label: Ham
# P(Spam|message): 1.0309309713551835e-42
# P(Ham|message): 1.8711953259625227e-39
# Label: Ham
# P(Spam|message): 8.667340486257425e-117
# P(Ham|message): 1.0245961740327638e-104
# Label: Ham
# P(Spam|message): 1.6190340519652078e-172
# P(Ham|message): 6.928028815503153e-162
# Label: Ham
# P(Spam|message): 1.2079937988063712e-179
# P(Ham|message): 3.851951719875185e-201
# Label: Spam
# P(Spam|message): 1.6286996361205925e-25
# P(Ham|message): 5.191958737220282e-22
# Label: Ham
# P(Spam|message): 1.8935105001852783e-81
# P(Ham|message): 5.299975225088229e-74
# Label: Ham
# P(Spam|message): 1.3793053848287397e-187
# P(Ham|message): 1.2347659667244568e-205
# Label: Spam
# P(Spam|message): 9.89474781083177e-182
# P(Ham|message): 2.2741130022206648e-187
# Label: Spam
# P(Spam|message): 3.972122237567601e-88
# P(Ham|message): 1.5681087484560539e-83
# Label: Ham
# P(Spam|message): 1.1273491976871784e-124
# P(Ham|message): 3.078886814907286e-111
# Label: Ham
# P(Spam|message): 3.089430695767773e-51
# P(Ham|message): 2.246089790811313e-48
# Label: Ham
# P(Spam|message): 1.8297068611730056e-53
# P(Ham|message): 2.9781312378387956e-50
# Label: Ham
# P(Spam|message): 7.921223027545981e-168
# P(Ham|message): 2.80285812218288e-176
# Label: Spam
# P(Spam|message): 4.294392932332404e-108
# P(Ham|message): 3.2257337368450626e-101
# Label: Ham
# P(Spam|message): 7.108734693361109e-112
# P(Ham|message): 6.630833049746618e-106
# Label: Ham
# P(Spam|message): 9.274364005112089e-170
# P(Ham|message): 2.7861402268900798e-182
# Label: Spam
# P(Spam|message): 2.6778636852524415e-216
# P(Ham|message): 1.212140106342742e-207
# Label: Ham
# P(Spam|message): 9.697957226603436e-30
# P(Ham|message): 4.708456768652897e-27
# Label: Ham
# P(Spam|message): 1.7884717376502745e-173
# P(Ham|message): 2.447360040073257e-192
# Label: Spam
# P(Spam|message): 3.888829551633565e-202
# P(Ham|message): 1.463489685775371e-188
# Label: Ham
# P(Spam|message): 1.1479019405338994e-95
# P(Ham|message): 1.557748681804931e-87
# Label: Ham
# P(Spam|message): 6.801943088638539e-62
# P(Ham|message): 9.95601769673103e-59
# Label: Ham
# P(Spam|message): 1.8569223083279043e-109
# P(Ham|message): 3.557738911359978e-99
# Label: Ham
# P(Spam|message): 3.568701186641773e-94
# P(Ham|message): 1.384919856025011e-84
# Label: Ham
# P(Spam|message): 1.48238440325582e-45
# P(Ham|message): 7.961581149548461e-43
# Label: Ham
# P(Spam|message): 1.9748656479078405e-143
# P(Ham|message): 2.414001002217731e-162
# Label: Spam
# P(Spam|message): 6.279028184350178e-178
# P(Ham|message): 2.28188361846005e-202
# Label: Spam
# P(Spam|message): 5.034587371684834e-143
# P(Ham|message): 5.293074705184192e-134
# Label: Ham
# P(Spam|message): 3.2333488613338626e-72
# P(Ham|message): 7.841465910896516e-66
# Label: Ham
# P(Spam|message): 7.556980229362512e-51
# P(Ham|message): 1.0353379128800667e-48
# Label: Ham
# P(Spam|message): 2.8710927220824076e-53
# ...
# Label: Ham
# P(Spam|message): 6.659286588797969e-68
# P(Ham|message): 6.304621017461481e-63
# Label: Ham
# P(Spam|message): 1.529582052130157e-36
# P(Ham|message): 8.115142478578147e-33
# Label: Ham
# P(Spam|message): 1.0003061377364536e-88
# P(Ham|message): 6.308817524874639e-82
# Label: Ham
# P(Spam|message): 4.8140921837268134e-17
# P(Ham|message): 2.6417302340987924e-14
# Label: Ham
# P(Spam|message): 9.578711251219256e-46
# P(Ham|message): 2.04763218207754e-42
# Label: Ham
# P(Spam|message): 9.606116083861686e-219
# P(Ham|message): 1.3148701061857938e-211
# Label: Ham
# P(Spam|message): 6.098924678332086e-183
# P(Ham|message): 2.0994477343705631e-168
# Label: Ham
# P(Spam|message): 9.510665427664655e-27
# P(Ham|message): 2.731692029605764e-25
# Label: Ham
# P(Spam|message): 6.446946466851609e-187
# P(Ham|message): 2.463560204617022e-198
# Label: Spam
# P(Spam|message): 2.8384249484743426e-57
# P(Ham|message): 2.452056567105331e-54
# Label: Ham
# P(Spam|message): 1.033935948400595e-36
# P(Ham|message): 6.510168475916629e-32
# Label: Ham
# P(Spam|message): 6.068199460698032e-70
# P(Ham|message): 3.299747399406997e-64
# Label: Ham
# P(Spam|message): 2.5556533768878047e-43
# P(Ham|message): 5.341403829530307e-39
# Label: Ham
# P(Spam|message): 6.502941131131727e-138
# P(Ham|message): 3.8513834392465136e-154
# Label: Spam
# P(Spam|message): 1.033935948400595e-36
# P(Ham|message): 6.510168475916629e-32
# Label: Ham
# P(Spam|message): 1.953742132619428e-64
# P(Ham|message): 9.299750258602784e-60
# Label: Ham
# P(Spam|message): 1.7884717376502745e-173
# P(Ham|message): 2.447360040073257e-192
# Label: Spam
# P(Spam|message): 1.342091613154176e-152
# P(Ham|message): 9.355203928312884e-146
# Label: Ham
# P(Spam|message): 2.7613056706405794e-117
# P(Ham|message): 3.1362657453812827e-113
# Label: Ham
# P(Spam|message): 3.8989496137239314e-156
# P(Ham|message): 3.897788862526616e-173
# Label: Spam
# P(Spam|message): 1.681989456489033e-30
# P(Ham|message): 5.497573490210715e-29
# Label: Ham
# P(Spam|message): 1.1833304066527122e-210
# P(Ham|message): 1.6760092201714908e-238
# Label: Spam
# P(Spam|message): 4.182546891813955e-148
# P(Ham|message): 6.78860712472283e-138
# Label: Ham
# P(Spam|message): 4.706191213409604e-37
# P(Ham|message): 2.80559220237612e-32
# Label: Ham
# P(Spam|message): 1.1962007436266631e-192
# P(Ham|message): 7.711210088824623e-212
# Label: Spam
# P(Spam|message): 2.2728764382944118e-36
# P(Ham|message): 1.7145033424386307e-31
# Label: Ham
# P(Spam|message): 2.821223920466454e-30
# P(Ham|message): 2.1424967598169867e-25
# Label: Ham
# P(Spam|message): 4.547937989504045e-59
# P(Ham|message): 6.160763202976436e-55
# Label: Ham
# P(Spam|message): 4.1911508768294207e-156
# P(Ham|message): 1.8700210974970463e-172
# Label: Spam
# P(Spam|message): 3.1919744482394694e-119
# P(Ham|message): 2.010403788811831e-114
# Label: Ham
# P(Spam|message): 2.6053827228005316e-119
# P(Ham|message): 7.746604259190678e-109
# Label: Ham
# P(Spam|message): 5.582921424911644e-192
# P(Ham|message): 2.7972576320489496e-214
# Label: Spam
# P(Spam|message): 9.196493556954916e-209
# P(Ham|message): 8.52530763780232e-200
# Label: Ham
# P(Spam|message): 1.5805728535820477e-104
# P(Ham|message): 1.3139269579628069e-99
# Label: Ham
# P(Spam|message): 1.520310699348495e-58
# P(Ham|message): 4.222402936789831e-55
# Label: Ham
# P(Spam|message): 1.2271451497232585e-90
# P(Ham|message): 5.316122972983817e-86
# Label: Ham
# P(Spam|message): 8.24587550035686e-165
# P(Ham|message): 4.434485070628777e-152
# Label: Ham
# P(Spam|message): 3.6901183860287964e-195
# P(Ham|message): 1.207942995192907e-218
# Label: Spam
# P(Spam|message): 9.69387772221428e-38
# P(Ham|message): 1.248063495616191e-33
# Label: Ham
# P(Spam|message): 3.0806269732403174e-188
# P(Ham|message): 5.568565784637228e-175
# Label: Ham
# P(Spam|message): 8.243137584568708e-92
# P(Ham|message): 1.331725667268712e-88
# Label: Ham
# P(Spam|message): 3.415065571003094e-09
# P(Ham|message): 1.942632626361068e-09
# Label: Spam
# P(Spam|message): 9.969865607004133e-108
# P(Ham|message): 3.879270601046872e-102
# Label: Ham
# P(Spam|message): 2.094199112555793e-58
# P(Ham|message): 1.2102499555947903e-54
# Label: Ham
# P(Spam|message): 3.473103481908629e-75
# P(Ham|message): 4.698175383286915e-73
# Label: Ham
# P(Spam|message): 3.642610303955114e-157
# P(Ham|message): 1.5291214740372683e-172
# Label: Spam
# P(Spam|message): 1.4144940970339597e-50
# P(Ham|message): 3.9952286269714752e-47
# Label: Ham
# P(Spam|message): 1.1383551903343649e-09
# P(Ham|message): 3.885265252722136e-09
# Label: Ham
# P(Spam|message): 1.033935948400595e-36
# P(Ham|message): 6.510168475916629e-32
# Label: Ham
# P(Spam|message): 1.0372243457780438e-131
# P(Ham|message): 1.847126162445578e-154
# Label: Spam
# P(Spam|message): 1.2038387359960637e-137
# P(Ham|message): 4.644806430032767e-127
# Label: Ham
# P(Spam|message): 4.959182672694938e-32
# P(Ham|message): 3.3508773581309503e-28
# Label: Ham
# P(Spam|message): 2.5186309958617368e-67
# P(Ham|message): 3.978626252525459e-60
# Label: Ham
# P(Spam|message): 5.982233301671474e-72
# P(Ham|message): 6.769634939668283e-63
# Label: Ham
# P(Spam|message): 6.73499007606167e-225
# P(Ham|message): 6.835407413891043e-214
# Label: Ham
# P(Spam|message): 5.937457105935749e-155
# P(Ham|message): 2.9151053633174975e-145
# Label: Ham
# P(Spam|message): 2.9957488881453915e-80
# P(Ham|message): 8.090426421423212e-86
# Label: Spam
# P(Spam|message): 1.3573134439688852e-131
# P(Ham|message): 1.9181845376306476e-126
# Label: Ham
# P(Spam|message): 3.597338225457899e-44
# P(Ham|message): 6.680002128843562e-41
# Label: Ham
# P(Spam|message): 1.603563313934995e-181
# P(Ham|message): 3.8798148096314034e-174
# Label: Ham
# P(Spam|message): 4.1492305493325555e-125
# P(Ham|message): 3.595708652670906e-114
# Label: Ham
# P(Spam|message): 2.7551647275772636e-74
# P(Ham|message): 2.1366982176011193e-71
# Label: Ham
# P(Spam|message): 4.686633626654995e-110
# P(Ham|message): 1.1783947335511283e-102
# Label: Ham
# P(Spam|message): 2.4648151980681283e-15
# P(Ham|message): 1.3814792640516625e-14
# Label: Ham
# P(Spam|message): 1.9739962325914866e-80
# P(Ham|message): 1.0639533537011611e-74
# Label: Ham
# P(Spam|message): 6.383156287348455e-198
# P(Ham|message): 2.0762566777666297e-191
# Label: Ham
# P(Spam|message): 3.2813498474698176e-56
# P(Ham|message): 2.283055964941135e-54
# Label: Ham
# P(Spam|message): 2.5622067132891017e-47
# P(Ham|message): 1.3022216453045427e-43
# Label: Ham
# P(Spam|message): 4.7362872800540854e-147
# P(Ham|message): 2.889952772604925e-147
# Label: Spam
# P(Spam|message): 1.3640568274766183e-171
# P(Ham|message): 4.985912799943066e-196
# Label: Spam
# P(Spam|message): 8.313680919470622e-117
# P(Ham|message): 3.515272717363415e-122
# Label: Spam
# P(Spam|message): 1.7615221896282965e-71
# P(Ham|message): 1.6581845039140841e-65
# Label: Ham
# P(Spam|message): 1.1534967213912796e-173
# P(Ham|message): 3.416901306757535e-198
# Label: Spam
# P(Spam|message): 1.6286996361205926e-24
# P(Ham|message): 3.261615104151203e-23
# Label: Ham
# P(Spam|message): 3.545634156026619e-159
# P(Ham|message): 7.051912951698351e-182
# Label: Spam
# P(Spam|message): 2.3289559898925894e-67
# P(Ham|message): 1.3584803357691191e-64
# Label: Ham
# P(Spam|message): 1.3950975779521843e-217
# P(Ham|message): 9.596579219939411e-198
# Label: Ham
# P(Spam|message): 7.664539628013868e-141
# P(Ham|message): 4.117191706025043e-131
# Label: Ham
# P(Spam|message): 1.2493932808891615e-75
# P(Ham|message): 2.457646664944014e-68
# Label: Ham
# P(Spam|message): 2.459785543285453e-87
# P(Ham|message): 1.912683038095422e-83
# Label: Ham
# P(Spam|message): 6.866230900190873e-73
# P(Ham|message): 4.120236256351928e-68
# Label: Ham
# P(Spam|message): 7.625606739208847e-49
# P(Ham|message): 3.621446000422612e-46
# Label: Ham
# P(Spam|message): 2.7551647275772636e-74
# P(Ham|message): 2.1366982176011193e-71
# Label: Ham
# P(Spam|message): 3.9189516515819517e-56
# P(Ham|message): 2.3786485094168696e-52
# Label: Ham
# P(Spam|message): 2.176298387903213e-103
# P(Ham|message): 1.3508878490402754e-96
# Label: Ham
# P(Spam|message): 1.7982465766595652e-83
# P(Ham|message): 1.6702493037159047e-77
# Label: Ham
# P(Spam|message): 7.718401357753295e-44
# P(Ham|message): 8.674551904867293e-43
# Label: Ham
# P(Spam|message): 4.1668026372361917e-50
# P(Ham|message): 1.5126040233213954e-44
# Label: Ham
# P(Spam|message): 7.722849096885374e-120
# P(Ham|message): 3.355453359843971e-112
# Label: Ham
# P(Spam|message): 4.601076472040674e-23
# P(Ham|message): 1.3425383347822379e-21
# Label: Ham
# P(Spam|message): 1.5112955766830536e-109
# P(Ham|message): 7.797105346626883e-101
# Label: Ham
# P(Spam|message): 1.158421774343221e-75
# P(Ham|message): 3.748596873949652e-71
# Label: Ham
# P(Spam|message): 2.2622979667505533e-143
# P(Ham|message): 8.226513324285244e-136
# Label: Ham
# P(Spam|message): 2.225466631799763e-157
# P(Ham|message): 5.350726879308784e-144
# Label: Ham
# P(Spam|message): 9.741797764487931e-129
# P(Ham|message): 4.722689459101845e-122
# Label: Ham
# P(Spam|message): 2.170703889654537e-114
# P(Ham|message): 3.2326490910117622e-108
# Label: Ham
# P(Spam|message): 7.755102177771424e-36
# P(Ham|message): 3.452062674948423e-33
# Label: Ham
# P(Spam|message): 5.082111867981468e-183
# P(Ham|message): 1.7647427223490358e-175
# Label: Ham
# P(Spam|message): 1.707271582639273e-216
# P(Ham|message): 7.586180971278682e-211
# Label: Ham
# P(Spam|message): 7.306529137770543e-29
# P(Ham|message): 2.3869153656749392e-27
# Label: Ham
# P(Spam|message): 1.1082749626318812e-131
# P(Ham|message): 6.0341671620546684e-123
# Label: Ham
# P(Spam|message): 3.937223471794172e-151
# P(Ham|message): 1.083767095018204e-170
# Label: Spam
# P(Spam|message): 6.807474410766909e-118
# P(Ham|message): 3.933444782261432e-105
# Label: Ham
# P(Spam|message): 1.7843122078283623e-80
# P(Ham|message): 6.65541102615969e-77
# Label: Ham
# P(Spam|message): 0.0
# P(Ham|message): 0.0
# Equal proabilities, have a human classify this!
# P(Spam|message): 0.0
# P(Ham|message): 0.0
# Equal proabilities, have a human classify this!
# P(Spam|message): 5.534365286119931e-40
# P(Ham|message): 2.2999950026718684e-36
# Label: Ham
# P(Spam|message): 1.864207254271977e-39
# P(Ham|message): 2.0802183890168604e-36
# Label: Ham
# P(Spam|message): 1.7200586952575728e-212
# P(Ham|message): 7.856688310472118e-206
# Label: Ham
# P(Spam|message): 9.783151695800835e-42
# P(Ham|message): 5.282803971307085e-40
# Label: Ham
# P(Spam|message): 1.1811541948955107e-49
# P(Ham|message): 3.5226710249405234e-46
# Label: Ham
# P(Spam|message): 6.87673330613698e-30
# P(Ham|message): 6.597223192503674e-27
# Label: Ham
# P(Spam|message): 1.9133165467155438e-225
# P(Ham|message): 2.977539944999046e-234
# Label: Spam
# P(Spam|message): 7.751835945430242e-58
# P(Ham|message): 2.4535768779798302e-54
# Label: Ham
# P(Spam|message): 1.8983786050871847e-191
# P(Ham|message): 3.552516554267657e-182
# Label: Ham
# P(Spam|message): 1.3512618427746664e-40
# P(Ham|message): 1.8038747881555955e-38
# Label: Ham
# P(Spam|message): 3.6790139628246193e-163
# P(Ham|message): 6.670621590271788e-148
# Label: Ham
# P(Spam|message): 8.477287607564488e-95
# P(Ham|message): 1.1350831998264509e-86
# Label: Ham
# P(Spam|message): 2.5885637808375887e-191
# P(Ham|message): 6.59004594969001e-176
# Label: Ham
# P(Spam|message): 2.480501614649066e-136
# P(Ham|message): 2.3643206533409764e-144
# Label: Spam
# P(Spam|message): 3.555766798300033e-202
# P(Ham|message): 2.6128471136265877e-190
# Label: Ham
# P(Spam|message): 1.0966296690370011e-57
# P(Ham|message): 7.812573993770334e-55
# Label: Ham
# P(Spam|message): 3.639777647520025e-134
# P(Ham|message): 1.0589815134192022e-128
# Label: Ham
# P(Spam|message): 6.60342717502851e-213
# P(Ham|message): 3.09967878422594e-232
# Label: Spam
# P(Spam|message): 0.0
# P(Ham|message): 0.0
# Equal proabilities, have a human classify this!
# P(Spam|message): 3.2297390680261995e-38
# P(Ham|message): 2.5489621914425475e-36
# Label: Ham
# P(Spam|message): 2.550464987926275e-48
# P(Ham|message): 5.101278283221695e-45
# Label: Ham
# P(Spam|message): 0.13458950201884254
# P(Ham|message): 0.8654104979811574
# Label: Ham
# P(Spam|message): 1.6886856835702322e-99
# P(Ham|message): 1.201432964249414e-91
# Label: Ham
# P(Spam|message): 2.5730196047389415e-61
# P(Ham|message): 1.3280836619714826e-57
# Label: Ham
# P(Spam|message): 8.580672160256743e-47
# P(Ham|message): 1.990542454488799e-45
# Label: Ham
# P(Spam|message): 2.7881756224050586e-238
# P(Ham|message): 2.4007331314849246e-224
# Label: Ham
# P(Spam|message): 1.0051734029057248e-45
# P(Ham|message): 5.783458964607269e-42
# Label: Ham
# P(Spam|message): 6.874203343004645e-50
# P(Ham|message): 4.62011435018302e-47
# Label: Ham
# P(Spam|message): 2.9688475305807474e-54
# P(Ham|message): 1.86960195471508e-51
# Label: Ham
# P(Spam|message): 2.750516992978443e-99
# P(Ham|message): 8.551601637914768e-92
# Label: Ham
# P(Spam|message): 4.0033334587199903e-146
# P(Ham|message): 1.798828250653318e-142
# Label: Ham
# P(Spam|message): 1.735758755743269e-159
# P(Ham|message): 6.609826623206713e-162
# Label: Spam
# P(Spam|message): 1.656814197234219e-38
# P(Ham|message): 5.2106008196491814e-36
# Label: Ham
# P(Spam|message): 2.7963108814079658e-39
# P(Ham|message): 1.1888690341799407e-34
# Label: Ham
# P(Spam|message): 6.413658488166993e-59
# P(Ham|message): 6.824548921141374e-56
# Label: Ham
# P(Spam|message): 1.9700563683961142e-227
# P(Ham|message): 8.278809932408325e-213
# Label: Ham
# P(Spam|message): 3.089532297850916e-75
# P(Ham|message): 1.32319376148828e-69
# Label: Ham
# P(Spam|message): 3.6759184322636545e-34
# P(Ham|message): 1.1477471959759915e-31
# Label: Ham
# P(Spam|message): 1.341204464960475e-125
# P(Ham|message): 2.904767918929721e-121
# Label: Ham
# P(Spam|message): 6.990777203519913e-38
# P(Ham|message): 1.4997915499778626e-36
# Label: Ham
# P(Spam|message): 2.2789317391533034e-69
# P(Ham|message): 4.664683657720912e-64
# Label: Ham
# P(Spam|message): 2.2253744415731497e-141
# P(Ham|message): 5.798314579280816e-132
# Label: Ham
# P(Spam|message): 1.6362278276730265e-73
# P(Ham|message): 2.3084285142420336e-71
# Label: Ham
# P(Spam|message): 2.839560489707075e-36
# P(Ham|message): 1.0536845254784892e-34
# Label: Ham
# P(Spam|message): 5.970510838010875e-147
# P(Ham|message): 4.02156959653324e-171
# Label: Spam
# P(Spam|message): 6.378919593751302e-123
# P(Ham|message): 4.415041409296132e-109
# Label: Ham
# P(Spam|message): 2.1588455664715622e-217
# P(Ham|message): 2.73606300217512e-200
# Label: Ham
# P(Spam|message): 1.363775234991108e-31
# P(Ham|message): 7.028658808169867e-30
# Label: Ham
# P(Spam|message): 1.3348908614505227e-58
# P(Ham|message): 1.1321628523882315e-56
# Label: Ham
# P(Spam|message): 2.77665139582987e-143
# P(Ham|message): 8.565352572551599e-134
# Label: Ham
# P(Spam|message): 5.679559460906411e-51
# P(Ham|message): 3.097504168798756e-47
# Label: Ham
# P(Spam|message): 1.8708872720117247e-21
# P(Ham|message): 1.3269017682535129e-20
# Label: Ham
# P(Spam|message): 1.925382194662379e-67
# P(Ham|message): 5.495075723002656e-75
# Label: Spam
# P(Spam|message): 4.311366775359108e-255
# P(Ham|message): 8.046695574177348e-242
# Label: Ham
# P(Spam|message): 4.34121838219758e-61
# P(Ham|message): 1.4112212519366294e-57
# Label: Ham
# P(Spam|message): 2.356644272045345e-156
# P(Ham|message): 7.755269811625907e-147
# Label: Ham
# P(Spam|message): 1.5939356456572733e-83
# P(Ham|message): 1.7164601683319308e-78
# Label: Ham
# P(Spam|message): 6.1513921900065675e-301
# P(Ham|message): 2.2930225806521353e-297
# Label: Ham
# P(Spam|message): 8.454976051864453e-51
# P(Ham|message): 2.3107144999970104e-48
# Label: Ham
# P(Spam|message): 3.416742358220357e-37
# P(Ham|message): 4.99654950548479e-32
# Label: Ham
# P(Spam|message): 3.148709195839185e-272
# P(Ham|message): 3.395020821423301e-266
# Label: Ham
# P(Spam|message): 7.461770822793216e-99
# P(Ham|message): 3.3184789980063336e-92
# Label: Ham
# P(Spam|message): 2.2245502371604685e-53
# P(Ham|message): 1.6740090260136095e-52
# Label: Ham
# P(Spam|message): 8.361321468566977e-67
# P(Ham|message): 4.7317692319582595e-62
# Label: Ham
# P(Spam|message): 1.2286170124119077e-244
# P(Ham|message): 1.9127578538890534e-237
# Label: Ham
# P(Spam|message): 2.3413779835932324e-52
# P(Ham|message): 7.64105782655806e-47
# Label: Ham
# P(Spam|message): 1.9430701292794523e-56
# P(Ham|message): 3.3817800063228645e-52
# Label: Ham
# P(Spam|message): 2.3114838982816897e-93
# P(Ham|message): 1.4503977260538563e-89
# Label: Ham
# P(Spam|message): 1.3447864677506482e-106
# P(Ham|message): 6.376045847558489e-99
# Label: Ham
# P(Spam|message): 5.084963336342067e-66
# P(Ham|message): 1.713411811102176e-63
# Label: Ham
# P(Spam|message): 4.499837779665928e-217
# P(Ham|message): 4.4965230434049296e-229
# Label: Spam
# P(Spam|message): 1.3576936280894848e-42
# P(Ham|message): 3.66671176398214e-41
# Label: Ham
